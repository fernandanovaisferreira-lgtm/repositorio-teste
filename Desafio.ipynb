# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandanovaisferreira-lgtm/repositorio-teste/blob/main/Desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Fernanda")
programado = input ("Qual sua Profissão?")
print ("programadora,sim")
print ("seja bem vindo a nossa equipe Fernanda, estamos Alegre ter um programado na nossa equipe.")
# Out:
# Fernanda
# Qual sua Profissão? programadora
# programadora,sim
# seja bem vindo a nossa equipe Fernanda, estamos Alegre ter um programado na nossa equipe.

# %%
print ("boa noite")
a_lua_ta_bonita = input ( "o ceu também")
print (f"{a_lua_ta_bonita} concordo ")
# Out:
# boa noite
# o ceu também sim
#  sim concordo

# %%
print ( "o dia está escurecendo rápido hoje")
frente_fria_ta_chegando = input ("você tem toda razão ")
print (f" é o mês do inverno, {frente_fria_ta_chegando} .")
# Out:
# o dia está escurecendo rápido hoje
# você tem toda razão  sim, percebi
#  é o mês do inverno,  sim, percebi .

# %%
print ("gato usava , botas preta")
input ("gato amarelo?")
# Out:
# gato usava , botas preta
# gato amarelo? sim
# ' sim'

# %%
print ("cachorro preto , usava coleira ")
cachorro_preto = input ("como assim")
print(f"sim coleira colorida, {cachorro_preto}")
# Out:
# cachorro preto , usava coleira
# como assim  azul , rosa, amarelo
# sim coleira colorida,   azul , rosa, amarelo
