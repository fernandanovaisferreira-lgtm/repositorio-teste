# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandanovaisferreira-lgtm/repositorio-teste/blob/main/Desafioif%26elif%26else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
adivinha = input ("a melancia é verde por fora e vermelha por dentro?")
if adivinha == ( "sim , é só olha"):
  print ("você acertou")
else:
  print ("talvez se tiver madura")
# Out:
# a melancia é verde por fora e vermelha por dentro? sim
# talvez se tiver madura

# %%
os_tres_porquinhos = input ("morava na fazenda, no cercado tijolo ou de palha ?")
if os_tres_porquinhos == ("palha"):
  print ("acertou")
elif os_tres_porquinhos == ("tijolo"):
  print ("acertou")
else:
  print ("os dois, pois é uma casa com telhado de palha e parede de tijolo.")
# Out:
# morava na fazenda, no cercado tijolo ou de palha ?sim
# os dois, pois é uma casa com telhado de palha e parede de tijolo.

# %%
os_tres_porquinhos = input ("morava na fazenda, no cercado tijolo ou de palha ?").lower().strip()
if os_tres_porquinhos == ("palha"):
  print ("acertou")
elif os_tres_porquinhos == ("tijolo"):
  print ("acertou")
else:
  print ("os dois, pois é uma casa com telhado de palha e parede de tijolo.")
# Out:
# morava na fazenda, no cercado tijolo ou de palha ? simm
# os dois, pois é uma casa com telhado de palha e parede de tijolo.

# %%
resposta = input ("quais das respostas é a certa ?").upper().strip()
print ("assinale a alternativa")
if resposta == "A":
  print ("alternativa A")
elif resposta == "B":
  print ("alternativa B")
elif resposta == "C":
  print ("alternativa C")
elif resposta == "D":
  print ("alternativa D")
# Out:
# quais das respostas é a certa ? c
# assinale a alternativa
# alternativa C

# %%
cristal = "azul"
if cristal == ("vermelho"):
  print("o portal pegou fogo na entrada")
elif cristal == ("azul"):
  print("o portal congelou , entrada liberada")
elif cristal == ("verde"):
  print("o portal pegou fogo na entrada")
else:
  print("o portal continua trancado")
# Out:
# o portal congelou , entrada liberada

# %%
pedido = "pizza"
if pedido =="calabresa":
  print("bem quente")
elif pedido =="queijo":
  print("bem quente")
elif pedido =="frango":
  print("bem quente")
else:
  print("bem quente")
# Out:
# bem quente

# %%
sinal = "branco"
if sinal == ("verde"):
  print("siga o veiculo a frente")
elif sinal == ("amarelo"):
  print("atençao")
elif sinal ==("verrmelho"):
  print("pare")
else:
  print("siga")
# Out:
# siga

# %%
pastel = "sabor"
if pastel == ("queijo"):
  print ("sim de queijo")
elif pastel == ("carne"):
  print ("pode ser carne")
else:
  print ("o que você acha melhor, para me dizer")
# Out:
# o que você acha melhor, para me dizer
